# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("musk_csv.csv")

# %%
df.head()
# Out:
#    ID molecule_name molecule number  isomer number  conformation number  f1  \
# 0   1      MUSK-211             211              1                    1  46
# 1   2      MUSK-211             211              1                   10  41
# 2   3      MUSK-211             211              1                   11  46
# 3   4      MUSK-211             211              1                   12  41
# 4   5      MUSK-211             211              1                   13  41
#
#     f2   f3  f4   f5  ...    f158  f159  f160  f161  f162  f163  f164  f165  \
# 0 -108  -60 -69 -117  ...    -308    52    -7    39   126   156   -50  -112
# 1 -188 -145  22 -117  ...     -59    -2    52   103   136   169   -61  -136
# 2 -194 -145  28 -117  ...    -134  -154    57   143   142   165   -67  -145
# 3 -188 -145  22 -117  ...     -60    -4    52   104   136   168   -60  -135
# 4 -188 -145  22 -117  ...     -60    -4    52   104   137   168   -60  -135
#
#    f166  class
# 0    96      1
# 1    79      1
# ...

# %%
X = df.iloc[:,3:171]

# %%
X
# Out:
#       isomer number  conformation number  f1   f2   f3   f4   f5   f6   f7  \
# 0                 1                    1  46 -108  -60  -69 -117   49   38
# 1                 1                   10  41 -188 -145   22 -117   -6   57
# 2                 1                   11  46 -194 -145   28 -117   73   57
# 3                 1                   12  41 -188 -145   22 -117   -7   57
# 4                 1                   13  41 -188 -145   22 -117   -7   57
# 5                 1                   14  46 -194 -145   28 -117   72   57
# 6                 1                   15  47 -199 -106   28 -117   73   27
# 7                 1                   16  41 -199 -101   22 -117   -6   26
# 8                 1                   17  41 -199 -101   22 -117   -6   26
# 9                 1                   18  47 -199 -106   28 -117   73   27
# 10                1                   19  41 -199 -101   22 -117   -6   26
# ...

# %%
Y = df[['class']]

# %%
X = np.array(X)

# %%
Y = np.array(Y)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 1)

# %%
from sklearn import preprocessing

# %%
X_train= preprocessing.StandardScaler().fit(X_train).transform(X_train)
X_test= preprocessing.StandardScaler().fit(X_test).transform(X_test)
X_train.shape
# Out:
# /home/clasher/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/clasher/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# (5278, 168)

# %%
X_test.shape
# Out:
# (1320, 168)

# %%
Y_train.shape
# Out:
# (5278, 1)

# %%
Y_test.shape
# Out:
# (1320, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,Y_train)
LR
# Out:
# /home/clasher/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred = LR.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import log_loss

# %%
y_hat=LR.predict_proba(X_test)
pred_log_loss = metrics.log_loss(Y_test,y_hat)

# %%
pred_log_loss
# Out:
# 0.18644639214926317

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %%
LR_MODEL=LR.predict(X_test)
LR_MODEL_p= LR.predict_proba(X_test)
print("jaccard_similarity_score")
print(jaccard_similarity_score(Y_test, LR_MODEL))
print("f1_score")
print(f1_score(Y_test, LR_MODEL,average='weighted'))
print("LogLoss")
print(log_loss(Y_test, LR_MODEL_p))
# Out:
# jaccard_similarity_score
# 0.9477272727272728
# f1_score
# 0.946617552703649
# LogLoss
# 0.18644639214926317
